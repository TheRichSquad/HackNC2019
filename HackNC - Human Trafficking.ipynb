# %%
URL_NYC = "./sources/nyc_bedpage_scrape.html"

# %%
from bs4 import BeautifulSoup

with open(URL_NYC, encoding = "ISO-8859-1") as fp:
    soup = BeautifulSoup(fp, "lxml")

# %%
soup
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <title>Massage center in new-york | Spa and wellness center in new-york</title>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="RRJiY3Y3kM2SpYp9M9TEX1ulkXZu1naPyZLpjXrvxJA" name="google-site-verification"/>
# <meta content="if you are struggling to find the right place for massage center in new-york or spa and wellness center in new-york then bedpage.com is the right place to get satisfactory services from certified massage therapist." name="description"/>
# <meta content="massage center in new-york, spa and wellness center in new-york" name="keywords"/>
# <link href="https://www.bedpage.com/backpage-new-york/spa-and-massage" rel="canonical"/>
# <link href="https://www.bedpage.com/assets/logo/favicon.ico" rel="shortcut icon"/>
# <meta content="https://www.bedpage.com/" property="og:site_name"/>
# ...
