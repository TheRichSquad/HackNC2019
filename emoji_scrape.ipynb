# %%
URL_NYC = "./sources/scrape_test.txt"

# %%
with open('./sources/scrape_test.txt', encoding = 'utf-16') as myfile:
    data = myfile.read()

# %%
data
# Out:
# '\n\n\n<!DOCTYPE html>\n<html>\n\t<head>\n\t\t<title>Massage center in new-york | Spa and wellness center in new-york</title>\n\t\n\t<meta name="viewport" content="width=device-width, initial-scale=1.0" />\n\t<meta http-equiv="Content-Type" content="text/html; charset=utf-8" />\n\t<meta name="google-site-verification" content="RRJiY3Y3kM2SpYp9M9TEX1ulkXZu1naPyZLpjXrvxJA" />\n\t<meta name="description" content="if you are struggling to find the right place for massage center in new-york or spa and wellness center in new-york then bedpage.com is the right place to get satisfactory services from certified massage therapist." />\n\t<meta name="keywords" content="massage center in new-york, spa and wellness center in new-york" />\n\t<link rel="canonical" href="https://www.bedpage.com/backpage-new-york/spa-and-massage" />\n\t<link rel="shortcut icon" href="https://www.bedpage.com/assets/logo/favicon.ico" />\n\t<meta property="og:site_name" content="https://www.bedpage.com/" />\n\t<meta pro
# ...

# %%
import emoji

def extract_emoji(data):
    return ''.join(c for c in data if c in emoji.UNICODE_EMOJI)

extract_emoji(data)
# Out:
# '⭐⭐💋💦😛👑😏🤩💋📲💋❤💋❤👗🌺🌺✨🌺🌺☯🌻🍀🌻🍀🌻🔥🔥🎈🎈❤❤❤❤❤❤❤❤❤❤❤❤🌺🌺🔥🌺🌺🌺🔥🌺🌺🌺🌺🔥🌺🌺🌺🔥🔥🔥🔥🌺🔥❌⭕❌⭕❌⭕☎⭕❌⭕❌⭕❌⭕❌⭕❌⭕💋❤💋❤💋❤💋❤💋❤💋❤💋❤💋❤💋❤💋❤👗🎀🌠👗🎀🌠👗🎀🌠🌻🍀🌻🍀🌻💋🌻🍀🌻🍀🌻💋🌻🍀🌻🍀🌻💋🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥🔥💐🌸🌸💐💐🌸🌸💐💐🌸🌸💐💞💞💞💞💞💞💞💞💞💞💞💞💞💞💞💞💞💞💞💞💞💞💞💞💞💞💞💞💞💞💞💞💞💞💞💞💞💞💞💞💞💞❤❤❤💋❤❤❤❤❤💋❤❤❤❤❤💋❤❤❤❤❤💋❤❤❤❤❤💋❤❤❤❤❤💋❤❤❤❤❤💋❤❤🌹🌹🌹🌹💓🌹🌹💓❤❤❤❤❤❤❤🎁🎁🎁🎁🎁🎁👍🔴🔴🔴🔴🔴🔴🔴🔴🔴🔴🎁🎁🎁👍🔴🔴🔴🔴🔴🔴🔴🔴🔴🔴❤🖤💛💚🧡🖤❤💛🧡💚🖤❤💛🧡💚❤🖤💛💚🧡🖤❤💛🧡💚🖤❤💛🧡💚❤🖤💛💚🧡🖤❤💛🧡💚🖤❤💛🧡💚❤🖤💛💚🧡🖤❤💛🧡💚🖤❤💛🧡💚💦💦👅😘💦💦👅😘💦💦👅😘🌹🌹🌹🌹💓🌹🌹💓❤❤❤❤❤❤❤📸📽💲🔴🔴💲🎥🎬📸📽💲🔴🔴💲🎥🎬🌐❌❌❌📸📽💲🔴🔴💲🎥🎬🌐❌❌❌❌⭕❌⭕❌⭕☎
!DOCTYPE html>\n<html>\n\t<head>\n\t\t<title>Massage center in new-york | Spa and wellness center in new-york</title>\n\t\n\t<meta name="viewport" content="width=device-width, initial-scale=1.0" />\n\t<meta http-equiv="Content-Type" content="text/html; charset=utf-8" />\n\t<meta name="google-site-verification" content="RRJiY3Y3kM2SpYp9M9TEX1ulkXZu1naPyZLpjXrvxJA" />\n\t<meta name="description" content="if you are struggling to find the right place for massage center in new-york or spa and wellness center in new-york then bedpage.com is the right place to get satisfactory services from certified massage therapist." />\n\t<meta name="keywords" content="massage center in new-york, spa and wellness center in new-york" />\n\t<link rel="canonical" href="https://www.bedpage.com/backpage-new-york/spa-and-massage" />\n\t<link rel="shortcut icon" href="https://www.bedpage.com/assets/logo/favicon.ico" />\n\t<meta property="og:site_name" content="https://www.bedpage.com/" />\n\t<meta pro
# ...

# %%
import html2text
html = open("./sources/New_York_update.html",encoding="utf-64").read()
print (html2text.html2text(html))

# %%
import html2text
html = open("./sources/New_York_update.html",encoding="utf-64").read()
print (html2text.html2text(html))
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# <ipython-input-5-dbf5dbfd926e> in <module>()
#       1 import html2text
# ----> 2 html = open("./sources/New_York_update.html",encoding="utf-64").read()
#       3 print (html2text.html2text(html))
#
# LookupError: unknown encoding: utf-64

# %%
from bs4 import BeautifulSoup
html_report_part1 = open(URL_NYC,'r')

soup = BeautifulSoup( html_report_part1, "html.parser")
ppf = soup.get_text()
print (ppf)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-59-2fdaace500c1> in <module>()
#       2 html_report_part1 = open(URL_NYC,'r')
#       3
# ----> 4 soup = BeautifulSoup( html_report_part1, "html.parser")
#       5 ppf = soup.get_text()
#       6 print (ppf)
#
# ~\Anaconda3\lib\site-packages\bs4\__init__.py in __init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, **kwargs)
#     243
#     244         if hasattr(markup, 'read'):        # It's a file-type object.
# --> 245             markup = markup.read()
#     246         elif len(markup) <= 256 and (
#     247                 (isinstance(markup, bytes) and not b'<' in markup)
#
# ~\Anaconda3\lib\encodings\cp1252.py in decode(self, input, final)
#      21 class IncrementalDecoder(codecs.IncrementalDecoder):
#      22     def decode(self, input, final=False):
# ...

# %%
import emoji

def extract_emoji(str):
    return ''.join(c for c in str if c in emoji.UNICODE_EMOJI)

extract_emoji('🍒')
# Out:
# '🍒'

# %%
from lxml import html
import requests

# %%
page = requests.get('https://new-york.bedpage.com/backpage.com/TherapeuticMassage/')
tree = html.fromstring(page.content)

# %%
a = tree.path('')

# %%
import requests

import unicodedata

from bs4 import BeautifulSoup

html = requests.get("https://new-york.bedpage.com/backpage.com/TherapeuticMassage/")

soup = BeautifulSoup(html.content, "lxml")

soup = unicode(soup)

soup.find_all('🍒')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-47cb218053c6> in <module>()
#       9 soup = BeautifulSoup(html.content, "lxml")
#      10
# ---> 11 soup = unicode(soup)
#      12
#      13 soup.find_all('🍒')
#
# NameError: name 'unicode' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-0196c41e1a94> in <module>()
# ----> 1 soup=unicode(soup)
#
# NameError: name 'unicode' is not defined
